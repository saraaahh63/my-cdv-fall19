# %%
# Change directory to VSCode workspace root so that relative path loads work correctly. Turn this addition off with the DataScience.changeDirOnImportExport setting
# ms-python.python added
import os
try:
	os.chdir(os.path.join(os.getcwd(), '../../scraping-stuff'))
	print(os.getcwd())
except:
	pass

# %%
import requests
from bs4 import BeautifulSoup
# import time
# import numpy as np

html = requests.get('https://en.wikipedia.org/wiki/List_of_American_films_of_2009')

b = BeautifulSoup(html.text, 'lxml')
print(b.prettify())

table = b.find('table',{'class':'wikitable sortable'})

print(table)

title = []
director = []
actor = []
genre = []
company = []

# obj = {
#     "title": ,
#     "director": ,
#     "actor": ,
#     "genre": ,
#     "company": ,
# }

title_links = table.findAll('a')
links

for links in title_links:
    title.append(links.get('title'))

print(title)
# Out:
# ter', 'Amber Heard', 'Rhys Ifans', 'Chris Isaak', 'Austin Nichols', 'Lou Taylor Pucci', 'Mel Raido', 'Brad Renfro', 'The Informers', 'Bret Easton Ellis', 'Inglourious Basterds', 'Quentin Tarantino', 'Brad Pitt', 'Mélanie Laurent', 'Christoph Waltz', 'Daniel Brühl', 'Diane Kruger', 'Michael Fassbender', 'Eli Roth', 'Til Schweiger', 'Universal Pictures', 'The Weinstein Company', 'Ink (film)', 'Jamin Winans', 'The International (2009 film)', 'Tom Tykwer', 'Clive Owen', 'Naomi Watts', 'Columbia Pictures', 'Invictus (film)', 'Clint Eastwood', 'Morgan Freeman', 'Matt Damon', 'Warner Bros. Pictures', 'John Carlin (journalist)', 'An Invisible Sign', 'Jessica Alba', 'J. K. Simmons', 'Chris Messina', 'The Invention of Lying', 'Ricky Gervais', 'Ricky Gervais', 'Jennifer Garner', 'Jonah Hill', 'Louis C.K.', 'Rob Lowe', 'Tina Fey', 'Christopher Guest', 'Warner Bros. Pictures', 'It Might Get Loud', 'Davis Guggenheim', 'Jimmy Page', 'The Edge', 'Jack White', 'Sony Pictures Classics', "It's Complicated (film)", 'Nancy Meyers', 'Robert Adamson (actor)', 'Blanchard Ryan', 'Meryl Streep', 'Steve Martin', 'Alec Baldwin', 'Universal Pictures', 'Janky Promoters', 'Marcus Raboy', 'Ice Cube', 'Mike Epps', 'Young Jeezy', 'Third Rail Releasing', "Jennifer's Body", 'Karyn Kusama', 'Megan Fox', 'Amanda Seyfried', 'Johnny Simmons', 'J. K. Simmons', 'Amy Sedaris', 'Adam Brody', 'Comedy horror', 'Teen film', '20th Century Fox', 'Fox Atomic', 'Jonas Brothers: The 3D Concert Experience', 'Jonas Brothers', 'Demi Lovato', 'Taylor Swift', 'Christa B. Allen', 'Concert film', 'Walt Disney Pictures', 'Julie & Julia', 'Nora Ephron', 'Meryl Streep', 'Amy Adams', 'Stanley Tucci', 'Chris Messina', 'Linda Emond', 'Biography film', 'Columbia Pictures', 'My Life in France', "Alex Prud'homme", 'Julie Powell', 'Knowing (film)', 'Alex Proyas', 'Nicolas Cage', 'Summit Entertainment', 'Labor Pains', 'Lara Shapiro (page does not exist)', 'Lindsay Lohan', 'Luke Kirby', 'Cheryl Hines', 'Chris Parnell', 'Bridgit Mendler', 'Kevin Covais', 'Romantic comedy', 'Romantic film', 'First Look Studios', 'Laid to Rest (film)', 'Robert Green Hall', 'Bobbi Sue Luther', 'Kevin Gage (actor)', 'Sean Whalen', 'Johnathon Schaech', 'Thomas Dekker (actor)', 'Richard Lynch (actor)', 'Lena Headey', 'Direct-to-DVD', 'Anchor Bay Entertainment', 'Land of the Lost (film)', 'Brad Silberling', 'Will Ferrell', 'Danny McBride', 'Anna Friel', 'Jorma Taccone', 'Universal Pictures', 'Relativity Media', 'Land of the Lost (1974 TV series)', 'The Last House on the Left (2009 film)', 'Dennis Iliadis', 'Garret Dillahunt', 'Rhys Coiro', 'Martha MacIsaac', 'Riki Lindhome', 'Tony Goldwyn', 'Monica Potter', 'Spencer Treat Clark', 'Sara Paxton', 'Rogue Pictures', 'The Last House on the Left (1972 film)', 'Law Abiding Citizen', 'F. Gary Gray', 'Gerard Butler', 'Jamie Foxx', 'Colm Meaney', 'Bruce McGill', 'Regina Hall', 'Viola Davis', 'Overture Films', 'Life During Wartime (film)', 'Todd Solondz', 'Ally Sheedy', 'Gaby Hoffmann', 'Happiness (1998 film)', 'The Lightkeepers', 'Daniel Adams (director)', 'Richard Dreyfuss', 'Blythe Danner', 'Mamie Gummer', 'The Limits of Control', 'Jim Jarmusch', 'Isaach de Bankolé', 'Bill Murray', 'Tilda Swinton', 'Gael García Bernal', 'Focus Features', 'Love Happens', 'Aaron Eckhart', 'Jennifer Aniston', 'Universal Pictures', "Love N' Dancing", 'Robert Iscove', 'Amy Smart', 'Tom Malloy', 'Billy Zane', 'Dance film', 'The Lovely Bones (film)', 'Peter Jackson', 'Saoirse Ronan', 'Rachel Weisz', 'Mark Wahlberg', 'Stanley Tucci', 'DreamWorks Pictures', 'The Lovely Bones', 'Alice Sebold', 'Lymelife', 'Derick Martini', 'Alec Baldwin', 'Emma Roberts', 'Rory Culkin', 'Kieran Culkin', 'Jill Hennessy', 'Timothy Hutton', 'Cynthia Nixon', 'Madea Goes to Jail', 'Tyler Perry', 'Sofía Vergara', 'Vanessa Ferlito', 'Derek Luke (actor)', 'Keshia Knight Pulliam', 'David Mann (actor)', 'Ion Overman', 'RonReaco Lee', 'Viola Davis', 'Lionsgate', 'Madea Goes to Jail (play)', 'The Maiden Heist', 'Peter Hewitt (film dir ...
