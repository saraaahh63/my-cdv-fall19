# %%
# Change directory to VSCode workspace root so that relative path loads work correctly. Turn this addition off with the DataScience.changeDirOnImportExport setting
# ms-python.python added
import os
try:
	os.chdir(os.path.join(os.getcwd(), '../../scraping-stuff'))
	print(os.getcwd())
except:
	pass

# %%
import requests
from bs4 import BeautifulSoup
from pprint import pprint
import json

html = requests.get('https://en.wikipedia.org/wiki/List_of_American_films_of_2013')

e = BeautifulSoup(html.text, 'lxml')

table = e.find('table',{'class':'wikitable sortable'})
print(table)

data = []

links2013 = table.findAll('tr')
for rows in links2013[1:]:
    cells = rows.findAll('td')
    movie = cells[0].find('a').contents[0]
    director = cells[1].get_text()
    cast = cells[2].get_text()
    genre = cells[3].get_text()
    company = cells[4].get_text()

    director = director.replace('\n', '').replace('\r', '')
    cast = cast.replace('\n', '').replace('\r', '')
    genre = genre.replace('\n', '').replace('\r', '')
    company = company.replace('\n', '').replace('\r', '')

    obj = dict()
    obj["movie"] = movie
    obj["director"] = director
    obj["cast"] = cast
    obj["genre"] = genre
    obj["company"] = company
    obj["year"] = '2013'

    data.append(obj)

print(data)
# Out:
# movie': 'Runner Runner', 'director': 'Brad Furman', 'cast': 'Justin Timberlake, Gemma Arterton, Anthony Mackie, Ben Affleck, David Costabile, Sam Palladio, Oliver Cooper', 'genre': 'Thriller', 'company': '20th Century Fox', 'year': '2013'}, {'movie': 'Safe Haven', 'director': 'Lasse Hallström', 'cast': 'Josh Duhamel, Julianne Hough, Cobie Smulders, David Lyons', 'genre': 'Romantic thriller', 'company': 'RelativityBased on the novel of the same name by Nicholas Sparks', 'year': '2013'}, {'movie': 'Salinger', 'director': 'Shane Salerno', 'cast': 'About the reclusive writer J. D. Salinger.', 'genre': 'Documentary', 'company': 'The Weinstein Company', 'year': '2013'}, {'movie': 'The Saratov Approach', 'director': 'Garrett Batty', 'cast': 'The Kidnapping of Mormon Missionaries in Russia in 1998.', 'genre': 'Thriller', 'company': 'Saratov Films', 'year': '2013'}, {'movie': 'Savannah', 'director': 'Annette Haywood-Carter', 'cast': 'Jim Caviezel, Jaimie Alexander, Chiwetel Ejiofor, Jack McBrayer, Sam Shepard', 'genre': 'Drama', 'company': 'Ketchup Entertainment', 'year': '2013'}, {'movie': 'Saving Lincoln', 'director': 'Salvador Litvak', 'cast': 'Tom Amandes, Lea Coco, Penelope Ann Miller, Bruce Davison, Creed Bratton', 'genre': 'Biographical', 'company': 'Lane Street Pictures', 'year': '2013'}, {'movie': 'Saving Mr. Banks', 'director': 'John Lee Hancock', 'cast': 'Emma Thompson, Tom Hanks, Paul Giamatti, Jason Schwartzman, Colin Farrell', 'genre': 'Dramedy', 'company': 'Disney', 'year': '2013'}, {'movie': 'Saving Santa', 'director': 'Leon Joosen', 'cast': 'Martin Freeman, Tim Curry, Noel Clarke, Tim Conway, Pam Ferris', 'genre': 'Animated', 'company': 'The Weinstein Company, Direct-to-video', 'year': '2013'}, {'movie': 'Scary Movie 5', 'director': 'Malcolm D. Lee', 'cast': "Ashley Tisdale, Simon Rex, Erica Ash, Katrina Bowden, Heather Locklear, Terry Crews, J. P. Manoux, Mac Miller, Jerry O'Connell, Molly Shannon, Snoop Dogg, Kate Walsh, Katt Williams, Sarah Hyland, Bow Wow, Jasmine Guy, Lil Duval, Chris Elliott, Kendra Wilkinson, Audrina Patridge, Tyler Posey, Mike Tyson, Charlie Sheen, Lindsay Lohan", 'genre': 'Horror comedy, Parody', 'company': 'Dimension Films, The Weinstein CompanyPreceded by Scary Movie 4 (2006)', 'year': '2013'}, {'movie': 'Scenic Route', 'director': 'Kevin and Michael Goetz', 'cast': 'Josh Duhamel, Dan Fogler', 'genre': 'Psychological thriller', 'company': 'Vertical Entertainment, Anonymous Content', 'year': '2013'}, {'movie': 'Scrapper', 'director': 'Brady Hall', 'cast': 'Michael Beach, Anna Giles, Aidan Gillen', 'genre': 'Drama', 'company': 'N/A', 'year': '2013'}, {'movie': 'Season of Miracles', 'director': 'Dave Moody', 'cast': 'John Schneider, Grayson Russell, Andrew Wilson Williams, Nancy Stafford', 'genre': 'Drama', 'company': 'Gaiam Vivendi EntertainmentBased on the novel of the same name by Rusty Whitener', 'year': '2013'}, {'movie': 'Sex Boss', 'director': 'Jackson Stewart', 'cast': 'Curtiss Frisle, Graham Skipper, Chase Williamson', 'genre': 'Dramedy', 'company': '531 Productions', 'year': '2013'}, {'movie': 'The Secret Life of Walter Mitty', 'director': 'Ben Stiller', 'cast': 'Ben Stiller, Kristen Wiig, Shirley MacLaine, Adam Scott, Kathryn Hahn, Sean Penn', 'genre': 'Dramedy', 'company': '20th Century FoxBased on the short story of the same name by James Thurber', 'year': '2013'}, {'movie': 'Sexy Evil Genius', 'director': 'Shawn Piller', 'cast': 'Katee Sackhoff, Michelle Trachtenberg, Anthony Michael Hall, Seth Green', 'genre': 'Comedy', 'company': 'Lionsgate, Direct-to-video', 'year': '2013'}, {'movie': 'Shadow People', 'director': 'Matthew Arnold', 'cast': 'Dallas Roberts, Alison Eastwood, Anne Dudek, Mariah Bonner, Mattie Liptak', 'genre': 'Horror', 'company': 'Anchor Bay Films, Direct-to-video', 'year': '2013'}, {'movie': 'She Wants Me', 'director': 'Rob Margolies', 'cast': 'Josh Gad, Kristen Ruhlin, Charlie Sheen, Hilary Duff', 'genre': 'Comedy', 'company': 'Lionsgate', 'year': '2013'}, {'mov ...
